# %%
import get_information as gi
import connections as cnnt

# %%
to_craw_list = gi.make_craw_list()
print(to_craw_list)
# Out:
# ['172420', '152669', '162014', '159647', '154285', '68291', '168017', '174804', '174811', '152689', '156098', '158558', '104390', '173958', '158623', '166482', '81240', '147388', '167049', '168693', '171441', '167100', '174257', '165321', '171413', '144693', '154550', '171415', '143776', '170206', '174806', '158178', '164183', '155263', '162395', '171414', '159105', '144959', '174617', '170139', '149236', '154226', '171822', '156584', '170289', '167048', '94131', '172034', '159877', '165020', '164684', '162874', '154251', '164290', '136315', '157243', '159827', '173459', '162715', '142250', '10230', '173653', '159366', '158611', '150658', '159311', '155567', '164719', '153936', '171828', '165722', '106360', '164979', '164335', '156912', '169349', '144379', '99093', '154112', '153621', '155123', '14125', '20324', '46954', '10593', '106027', '30012']

# %%
cnnt.initialize()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-4-5d91b915aa85> in <module>()
# ----> 1 cnnt.initialize()
#
# D:\workspace\Chatbot\Chatbot_Project\connections.py in initialize()
#      34     curs = cursor()[0]
#      35     delete = '''TRUNCATE TABLE BaseMovieInfo'''
# ---> 36     curs.execute(delete)
#      37     curs.close()
#      38     curs = cursor()[0]
#
# ~\Miniconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Miniconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     891                 sql = sql.encode(self.encoding, 'surrogateescape')
#     892         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 893         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     894         return self._affected_rows
#     895
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#    1101         else:
#    1102             result = MySQLResult(self)
# -> 1103             result.read()
#    1104         self._result = result
#    1105         if result.server_status is not None:
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1394     def read(self):
#    1395         try:
# -> 1396             first_packet = self.connection._read_packet()
#    1397
#    1398             if first_packet.is_ok_packet():
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#    1057
#    1058         packet = packet_type(buff, self.encoding)
# -> 1059         packet.check_error()
#    1060         return packet
#    1061
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# ~\Miniconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1701, 'Cannot truncate a table referenced in a foreign key constraint (`dbtoday`.`actorsofmovie`, CONSTRAINT `actorsofmovie_ibfk_1` FOREIGN KEY (`movie_code`) REFERENCES `dbtoday`.`basemovieinfo` (`movie_code`))')

# %%
# for i in range(len(to_craw_list)):
#     gi.get_by_moviecode(to_craw_list[i])
# print("끝")

for i in range(1):
    gi.get_by_moviecode(to_craw_list[i])
print("끝")
# Out:
# akay1
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# ~\Miniconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~\Miniconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     892         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 893         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     894         return self._affected_rows
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#    1102             result = MySQLResult(self)
# -> 1103             result.read()
#    1104         self._result = result
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1395         try:
# -> 1396             first_packet = self.connection._read_packet()
#    1397
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#    1058         packet = packet_type(buff, self.encoding)
# -> 1059         packet.check_error()
#    1060         return packet
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in check_error(self)
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#
# ~\Miniconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1241, 'Operand should contain 1 column(s)')
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-5-e21abba0760b> in <module>()
#       4
#       5 for i in range(1):
# ----> 6     gi.get_by_moviecode(to_craw_list[i])
#       7 print("끝")
#
# D:\workspace\Chatbot\Chatbot_Project\get_information.py in get_by_moviecode(moviecode)
#      77     movieurl = f"https://movie.naver.com/movie/bi/mi/basic.nhn?code={moviecode}"
#      78     soup = BeautifulSoup(get_source(movieurl), "lxml")
# ---> 79     a = get_movie_info(moviecode, soup)
#      80     return a
#      81
#
# D:\workspace\Chatbot\Chatbot_Project\get_information.py in get_movie_info(moviecode, soup)
#     160     session.merge(a)
#     161     session.merge(b)
# --> 162     session.commit()
#     163     session.close()
#     164     print("akay")
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#     941                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#     942
# --> 943         self.transaction.commit()
#     944
#     945     def prepare(self):
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#     465         self._assert_active(prepared_ok=True)
#     466         if self._state is not PREPARED:
# --> 467             self._prepare_impl()
#     468
#     469         if self._parent is None or self.nested:
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in _prepare_impl(self)
#     445                 if self.session._is_clean():
#     446                     break
# --> 447                 self.session.flush()
#     448             else:
#     449                 raise exc.FlushError(
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in flush(self, objects)
#    2252         try:
#    2253             self._flushing = True
# -> 2254             self._flush(objects)
#    2255         finally:
#    2256             self._flushing = False
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    2378         except:
#    2379             with util.safe_reraise():
# -> 2380                 transaction.rollback(_capture_exception=True)
#    2381
#    2382     def bulk_save_objects(
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    2342             self._warn_on_events = True
#    2343             try:
# -> 2344                 flush_context.execute()
#    2345             finally:
#    2346                 self._warn_on_events = False
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self)
#     389                     self.dependencies,
#     390                     postsort_actions):
# --> 391                 rec.execute(self)
#     392
#     393     def finalize_flush_changes(self):
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self, uow)
#     554                              uow.states_for_mapper_hierarchy(
#     555                                  self.mapper, False, False),
# --> 556                              uow
#     557                              )
#     558
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\persistence.py in save_obj(base_mapper, states, uowtransaction, single)
#     179         _emit_insert_statements(base_mapper, uowtransaction,
#     180                                 cached_connections,
# --> 181                                 mapper, table, insert)
#     182
#     183     _finalize_insert_update_commands(
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\orm\persistence.py in _emit_insert_statements(base_mapper, uowtransaction, cached_connections, mapper, table, insert, bookkeeping)
#     864                 else:
#     865                     result = cached_connections[connection].\
# --> 866                         execute(statement, params)
#     867
#     868                 primary_key = result.context.inserted_primary_key
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~\Miniconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\Miniconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Miniconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     891                 sql = sql.encode(self.encoding, 'surrogateescape')
#     892         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 893         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     894         return self._affected_rows
#     895
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#    1101         else:
#    1102             result = MySQLResult(self)
# -> 1103             result.read()
#    1104         self._result = result
#    1105         if result.server_status is not None:
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1394     def read(self):
#    1395         try:
# -> 1396             first_packet = self.connection._read_packet()
#    1397
#    1398             if first_packet.is_ok_packet():
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#    1057
#    1058         packet = packet_type(buff, self.encoding)
# -> 1059         packet.check_error()
#    1060         return packet
#    1061
#
# ~\Miniconda3\lib\site-packages\pymysql\connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# ~\Miniconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1241, 'Operand should contain 1 column(s)') [SQL: 'INSERT INTO `DetailedBaseMovieInfo` (movie_code, movie_name_eng, produce_year, genre_list, nation_list, flim_class, story, story_detail) VALUES (%(movie_code)s, %(movie_name_eng)s, %(produce_year)s, %(genre_list)s, %(nation_list)s, %(flim_class)s, %(story)s, %(story_detail)s)'] [parameters: {'movie_code': '172420', 'movie_name_eng': 'Hereditary', 'produce_year': '2017', 'genre_list': ['미스터리', '공포'], 'nation_list': ['미국'], 'flim_class': '15세 관람가', 'story': '가족이기에 피할 수 없는 운명이 그들을 덮쳤다!', 'story_detail': '‘애니’는 일주일 전 돌아가신 엄마의 유령이 집에 나타나는 것을 느낀다. \n\n애니가 엄마와 닮았다며 접근한 수상한 이웃 ‘조안’을 통해 엄마의 비밀을 발견하고, \n\n자신이 엄마와 똑같은 일을 저질렀음을 알게 된다. \n\n그리고 마침내 애니의 엄마로부터 시작돼 \n\n아들 ‘피터’와 딸 ‘찰리’에게까지 이어진 저주의 실체가 정체를 드러내는데…'}] (Background on this error at: http://sqlalche.me/e/2j85)
