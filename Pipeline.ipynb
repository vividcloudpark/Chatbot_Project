# %%
import get_information as gi
import connections as cnnt
import show_movie_trend as smd
import flask_bot
import datetime
# Out:
# /home/hyuna/anaconda3/envs/db/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '
# /home/hyuna/anaconda3/envs/db/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
now = datetime.datetime.now().date().strftime("%Y-%m-%d")
section = datetime.datetime.now().date() - datetime.timedelta(7)
section = section.strftime("%Y-%m-%d")
now,section
# Out:
# ('2018-06-13', '2018-06-06')

# %%
to_craw_list_op = gi.make_craw_list("op")
print(to_craw_list_op)
to_craw_list_pre = gi.make_craw_list("pre")
print(to_craw_list_pre)
# Out:
# ['159892', '153675', '174878', '174809', '174810', '172420', '162014', '152669', '159647', '154285', '168017', '68291', '174811', '174804', '152689', '156098', '104390', '173958', '158623', '166482', '147388', '167049', '168693', '81240', '171441', '174257', '165321', '171413', '154550', '143776', '171415', '144693', '170206', '158178', '164183', '155263', '159105', '171414', '162395', '144959', '149236', '171822', '154226', '156584', '170289', '167048', '172034', '165020', '164684', '154251', '169347', '164290', '136315', '157243', '159827', '173459', '162715', '142250', '10230', '173653', '158611', '150658', '159311', '171440', '155567', '164719', '153936', '171828', '162869', '106360', '164979', '164335', '156912', '144379', '99093', '158910', '162933', '154112', '153621', '155123', '152173', '145376', '67786', '132989', '38851', '10593', '106027', '30012']
# ['162854', '163893', '163900', '172469', '168405', '150097', '167064', '90965', '146566', '162423', '163824', '169899', '143416', '151145', '62266', '169647', '169240', '175617', '163682', '167787', '51548', '175322', '175365', '152680', '162098', '164297', '149049', '168303', '15006', '137688', '175320', '171501', '174798', '144785', '166476', '164151', '144330', '175325', '140285', '17170', '170859', '175614', '172344', '172113', '154222', '172174', '140288', '164115', '161833', '158890', '172003', '160375', '174805', '109906', '136990', '159839', '162265', '168030', '167697', '175727', '164916', '152661', '169015', '169643', '174807', '152156', '132996', '119428', '154255', '150688', '156496', '171725', '109193', '154672']

# %%
cnnt.initialize()
# Out:
# 초기화완료!

# %%
! pip install monthdelta
# Out:
# Collecting monthdelta
#   Downloading https://files.pythonhosted.org/packages/d2/82/9043e804fc40e8f96aae7c067244cdf5d8e3eb28748c9d3655e7e0231371/MonthDelta-0.9.1.tar.gz
# Building wheels for collected packages: monthdelta
#   Running setup.py bdist_wheel for monthdelta ... done
#   Stored in directory: /home/hyuna/.cache/pip/wheels/5e/e9/68/c0cb0cefe6fdd49ce42a99196b272748d2d823c18c7af612cf
# Successfully built monthdelta
# Installing collected packages: monthdelta
# Successfully installed monthdelta-0.9.1
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import monthdelta
datetime.datetime.now() + monthdelta.monthdelta(3)
# Out:
# datetime.datetime(2018, 9, 13, 21, 37, 42, 435137)

# %%
flask_bot.insert_trend(14)
# Out:
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# Inserted Succesfully!
# Data already exists
# Data already exists
# Data already exists
# image saved

# %%
# smd.query_and_draw('2018-06-13', '2018-01-06')
# smd.insert_movie_audiance_num_per_date(datetime.datetime.now().date(), 7)
# Out:
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
# Data already exists
#                                   20180607 20180608 20180609 20180610  \
# 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이     1796     1605    24723    26292
# 데드풀 2                                 8502    10421    15829    12481
# 독전                                   68602    84347   168854   148113
# 미드나잇 선                                 NaN     1003      NaN      NaN
# 버닝                                    1289     1411     2126      NaN
# 벅스 프렌즈                                 NaN      NaN     5047     6056
# 아바타                                    NaN      NaN      NaN      NaN
# 아이 필 프리티                             11274    14011    28274    25607
# 어벤져스: 인피니티 워                          2055     2241     4062     3575
# 여중생A                                   NaN      NaN      NaN      NaN
# 오션스8                                  2824     1259      NaN      NaN
# 유전                                   17859    19800    28048    23632
# 쥬라기 월드: 폴른 킹덤                       231830   312529   791349   703655
# 탐정: 리턴즈                               1908      NaN      NaN      NaN
# 피터 래빗                                  NaN      NaN     2685     3173
# 허스토리                                   NaN      NaN      NaN      NaN
# 호비와 매직 아일랜드                            NaN      NaN      NaN     1947
#
#                                   20180611 20180612  20180613
# 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이     1046      NaN       NaN
# 데드풀 2                                 6564     8218       NaN
# 독전                                   52889    61753       NaN
# 미드나잇 선                                 NaN      NaN       NaN
# 버닝                                     NaN     1153       NaN
# 벅스 프렌즈                                 NaN      NaN       NaN
# 아바타                                    NaN     1455       NaN
# 아이 필 프리티                             11246    14812       NaN
# 어벤져스: 인피니티 워                          1954     2271       NaN
# 여중생A                                  1141      NaN       NaN
# 오션스8                                   NaN      NaN       NaN
# 유전                                   11234    17405       NaN
# 쥬라기 월드: 폴른 킹덤                       143991   185616       NaN
# 탐정: 리턴즈                               3330     2787       NaN
# 피터 래빗                                  NaN      NaN       NaN
# 허스토리                                  2409     4558       NaN
# 호비와 매직 아일랜드                            NaN      NaN       NaN

# %%
for i in range(len(to_craw_list_op)):
    gi.get_by_moviecode(to_craw_list_op[i])
print("현재상영작 저장 완료!")

for i in range(len(to_craw_list_pre)):
    gi.get_by_moviecode(to_craw_list_pre[i])
print("상영작 예정작 저장 완료!")
# Out:
# 10
# 159892 2018.06.13 데이터베이스에 저장 완료!
# 10
# 153675 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174878 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174809 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174810 2018.06.13 데이터베이스에 저장 완료!
# 10
# 172420 2018.06.07 데이터베이스에 저장 완료!
# 10
# 162014 2018.06.07 데이터베이스에 저장 완료!
# 10
# 152669 2018.06.07 데이터베이스에 저장 완료!
# 10
# 159647 2018.06.07 데이터베이스에 저장 완료!
# 10
# 154285 2018.06.06 데이터베이스에 저장 완료!
# 10
# 168017 2018.06.06 데이터베이스에 저장 완료!
# 10
# 68291 2018.06.06 데이터베이스에 저장 완료!
# 10
# 174811 2018.06.06 데이터베이스에 저장 완료!
# 10
# 174804 2018.06.06 데이터베이스에 저장 완료!
# 10
# 152689 2018.05.31 데이터베이스에 저장 완료!
# 10
# 156098 2018.05.31 데이터베이스에 저장 완료!
# 10
# 104390 2018.05.31 데이터베이스에 저장 완료!
# 10
# 173958 2018.05.31 데이터베이스에 저장 완료!
# 10
# 158623 2018.05.31 데이터베이스에 저장 완료!
# 10
# 166482 2018.05.31 데이터베이스에 저장 완료!
# 10
# 147388 2018.05.30 데이터베이스에 저장 완료!
# 10
# 167049 2018.05.30 데이터베이스에 저장 완료!
# 10
# 168693 2018.05.30 데이터베이스에 저장 완료!
# 10
# 81240 2018.05.30 데이터베이스에 저장 완료!
# 10
# 171441 2018.05.30 데이터베이스에 저장 완료!
# 10
# 174257 2018.05.24 데이터베이스에 저장 완료!
# 10
# 165321 2018.05.24 데이터베이스에 저장 완료!
# 10
# 171413 2018.05.24 데이터베이스에 저장 완료!
# 10
# 154550 2018.05.24 데이터베이스에 저장 완료!
# 10
# 143776 2018.05.24 데이터베이스에 저장 완료!
# 10
# 171415 2018.05.24 데이터베이스에 저장 완료!
# 10
# 144693 2018.05.24 데이터베이스에 저장 완료!
# 10
# 170206 2018.05.24 데이터베이스에 저장 완료!
# 10
# 158178 2018.05.22 데이터베이스에 저장 완료!
# 10
# 164183 2018.05.22 데이터베이스에 저장 완료!
# 10
# 155263 2018.05.17 데이터베이스에 저장 완료!
# 10
# 159105 2018.05.17 데이터베이스에 저장 완료!
# 10
# 171414 2018.05.17 데이터베이스에 저장 완료!
# 10
# 162395 2018.05.17 데이터베이스에 저장 완료!
# 10
# 144959 2018.05.17 데이터베이스에 저장 완료!
# 10
# 149236 2018.05.16 데이터베이스에 저장 완료!
# 10
# 171822 2018.05.16 데이터베이스에 저장 완료!
# 10
# 154226 2018.05.16 데이터베이스에 저장 완료!
# 10
# 156584 2018.05.10 데이터베이스에 저장 완료!
# 10
# 170289 2018.05.10 데이터베이스에 저장 완료!
# 10
# 167048 2018.05.10 데이터베이스에 저장 완료!
# 10
# 172034 2018.05.10 데이터베이스에 저장 완료!
# 10
# 165020 2018.05.09 데이터베이스에 저장 완료!
# 10
# 164684 2018.05.03 데이터베이스에 저장 완료!
# 10
# 154251 2018.05.03 데이터베이스에 저장 완료!
# 10
# 169347 2018.05.01 데이터베이스에 저장 완료!
# 21
# 164290 2017-06-10 데이터베이스에 저장 완료!
# 10
# 136315 2018.04.25 데이터베이스에 저장 완료!
# 10
# 157243 2018.04.25 데이터베이스에 저장 완료!
# 10
# 159827 2018.04.25 데이터베이스에 저장 완료!
# 10
# 173459 2018.04.19 데이터베이스에 저장 완료!
# 10
# 162715 2018.04.19 데이터베이스에 저장 완료!
# 10
# 142250 2018.04.19 데이터베이스에 저장 완료!
# 28
# 10
# 173653 2018.04.12 데이터베이스에 저장 완료!
# 10
# 158611 2018.04.04 데이터베이스에 저장 완료!
# 10
# 150658 2018.03.28 데이터베이스에 저장 완료!
# 10
# 159311 2018.03.22 데이터베이스에 저장 완료!
# 10
# 171440 2018.03.22 데이터베이스에 저장 완료!
# 10
# 155567 2018.03.08 데이터베이스에 저장 완료!
# 10
# 164719 2018.03.07 데이터베이스에 저장 완료!
# 10
# 153936 2018.01.25 데이터베이스에 저장 완료!
# 10
# 171828 2018.01.25 데이터베이스에 저장 완료!
# 10
# 162869 2017.12.28 데이터베이스에 저장 완료!
# 10
# 106360 2017.12.20 데이터베이스에 저장 완료!
# 10
# 164979 2017.12.14 데이터베이스에 저장 완료!
# 10
# 164335 2017.12.07 데이터베이스에 저장 완료!
# 10
# 156912 2017.12.07 데이터베이스에 저장 완료!
# 10
# 144379 2017.11.09 데이터베이스에 저장 완료!
# 10
# 99093 2017.11.09 데이터베이스에 저장 완료!
# 10
# 158910 2017.07.13 데이터베이스에 저장 완료!
# 10
# 162933 2017.06.01 데이터베이스에 저장 완료!
# 10
# 154112 2017.05.17 데이터베이스에 저장 완료!
# 10
# 153621 2017.04.13 데이터베이스에 저장 완료!
# 10
# 155123 2016.11.24 데이터베이스에 저장 완료!
# 10
# 152173 2016.08.17 데이터베이스에 저장 완료!
# 10
# 145376 2016.02.04 데이터베이스에 저장 완료!
# 10
# 67786 2015.06.11 데이터베이스에 저장 완료!
# 10
# 132989 2015.02.05 데이터베이스에 저장 완료!
# 10
# 38851 2005.09.16 데이터베이스에 저장 완료!
# 10
# 10593 1957.04.27 데이터베이스에 저장 완료!
# 10
# 106027 1957.01.01 데이터베이스에 저장 완료!
# 10
# 30012 1955.11.15 데이터베이스에 저장 완료!
# 현재상영작 저장 완료!
# 10
# 162854 2018.06.14 데이터베이스에 저장 완료!
# 10
# 163893 2018.06.14 데이터베이스에 저장 완료!
# 10
# 163900 2018.06.14 데이터베이스에 저장 완료!
# 10
# 172469 2018.06.14 데이터베이스에 저장 완료!
# 10
# 168405 2018.06.20 데이터베이스에 저장 완료!
# 10
# 150097 2018.06.21 데이터베이스에 저장 완료!
# 10
# 167064 2018.06.21 데이터베이스에 저장 완료!
# 10
# 90965 2018.06.21 데이터베이스에 저장 완료!
# 10
# 146566 2018.06.21 데이터베이스에 저장 완료!
# 10
# 162423 2018.06.21 데이터베이스에 저장 완료!
# 10
# 163824 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169899 2018.06.21 데이터베이스에 저장 완료!
# 10
# 143416 2018.06.21 데이터베이스에 저장 완료!
# 10
# 151145 2018.06.21 데이터베이스에 저장 완료!
# 31
# 62266 2009-12-17 데이터베이스에 저장 완료!
# 10
# 169647 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169240 2018.06.21 데이터베이스에 저장 완료!
# 10
# 175617 2018.06.21 데이터베이스에 저장 완료!
# 10
# 163682 2018.06.21 데이터베이스에 저장 완료!
# 10
# 167787 2018.06.27 데이터베이스에 저장 완료!
# 10
# 51548 2018.06.27 데이터베이스에 저장 완료!
# 10
# 175322 2018.06.27 데이터베이스에 저장 완료!
# 10
# 175365 2018.06.27 데이터베이스에 저장 완료!
# 10
# 152680 2018.06.27 데이터베이스에 저장 완료!
# 10
# 162098 2018.06.28 데이터베이스에 저장 완료!
# 10
# 164297 2018.06.28 데이터베이스에 저장 완료!
# 21
# 149049 2016-08-03 데이터베이스에 저장 완료!
# 10
# 168303 2018.06.28 데이터베이스에 저장 완료!
# 21
# 15006 2000-10-28 데이터베이스에 저장 완료!
# 7
# 7
# 7
# 7
# 7
# 7
# 10
# 164151 2018.07.04 데이터베이스에 저장 완료!
# 10
# 175325 2018.07.05 데이터베이스에 저장 완료!
# 10
# 140285 2018.07.05 데이터베이스에 저장 완료!
# 41
# 17170 1995-02-18 데이터베이스에 저장 완료!
# 10
# 170859 2018.07.11 데이터베이스에 저장 완료!
# 10
# 175614 2018.07.12 데이터베이스에 저장 완료!
# 10
# 172344 2018.07.19 데이터베이스에 저장 완료!
# 10
# 172113 2018.07.19 데이터베이스에 저장 완료!
# 10
# 172174 2018.07.26 데이터베이스에 저장 완료!
# 7
# 7
# 7
# 7
# 7
# 7
# 상영작 예정작 저장 완료!

# %%
smd.insert_movie_audience_num_per_date('2018-01-30',15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a8ead32631b1> in <module>()
# ----> 1 smd.insert_movie_audience_num_per_date('2018-01-30',15)
#
# NameError: name 'smd' is not defined

# %%
smd.query_and_draw('2018-01-30', '2018-01-15')
