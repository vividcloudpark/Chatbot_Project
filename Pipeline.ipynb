# %% [markdown]
# # DB Insert 를 위한 모듈들

# %%
import get_information as gi
import connections as cnnt
import show_movie_trend as smd
import flask_bot
import datetime

# %% [markdown]
# # 상영작, 상영예정작 Insert

# %%
to_craw_list_op = gi.make_craw_list("op")
print(to_craw_list_op)
to_craw_list_pre = gi.make_craw_list("pre")
print(to_craw_list_pre)
# Out:
# ['174393', '175325', '159839', '163749', '140285', '144330', '164151', '170267', '168303', '162098', '164297', '15006', '172160', '114057', '174402', '175322', '167787', '175365', '51548', '152680', '143416', '167064', '162423', '150097', '169240', '146566', '175617', '169647', '163824', '169899', '172005', '151145', '168405', '162854', '163893', '163900', '159892', '153675', '174810', '162014', '172420', '154285', '168017', '174811', '68291', '174804', '152689', '168693', '147388', '167049', '171413', '174257', '165321', '154550', '158178', '164183', '155263', '171414', '159105', '154226', '149236', '170289', '173466', '164684', '164290', '136315', '159827', '142250', '159311', '171440', '171828', '27414', '10173', '166583', '164335', '154458', '162933', '157564', '38546', '155123', '152173', '50749', '146548', '146311', '31368', '145376', '132610', '125466', '119563', '132989', '103719', '85141', '87663', '27267', '18783', '16581', '23971', '10593']
# ['171866', '176537', '175251', '160375', '170859', '152694', '144130', '174387', '175229', '169688', '166476', '175614', '161833', '149144', '160992', '98980', '172003', '176524', '84845', '136990', '158890', '167058', '168030', '172344', '17170', '160721', '157340', '172113', '134871', '154222', '174805', '109906', '177378', '172174', '71151', '163867', '173581', '162265', '174798', '171764', '154027', '167558', '175727', '167697', '154223', '173784', '153687', '164115', '169643', '66751', '175317', '159636', '172118', '140652', '164916', '171499', '152661', '173019', '169015', '174807', '174305', '152156', '162870', '174301', '177379', '176988', '132996', '119428', '160487', '168058', '154255', '150688', '156496', '171725', '109193', '154672']

# %%
for i in range(len(to_craw_list_op)):
    gi.get_by_moviecode(to_craw_list_op[i])
print("현재상영작 저장 완료!")

for i in range(len(to_craw_list_pre)):
    gi.get_by_moviecode(to_craw_list_pre[i])
print("상영작 예정작 저장 완료!")
# Out:
# 10
# 174393 2018.07.06 데이터베이스에 저장 완료!
# 10
# 175325 2018.07.05 데이터베이스에 저장 완료!
# 10
# 159839 2018.07.05 데이터베이스에 저장 완료!
# 10
# 163749 2018.07.05 데이터베이스에 저장 완료!
# 10
# 140285 2018.07.05 데이터베이스에 저장 완료!
# 10
# 144330 2018.07.04 데이터베이스에 저장 완료!
# 10
# 164151 2018.07.04 데이터베이스에 저장 완료!
# 10
# 170267 2018.06.28 데이터베이스에 저장 완료!
# 10
# 168303 2018.06.28 데이터베이스에 저장 완료!
# 10
# 162098 2018.06.28 데이터베이스에 저장 완료!
# 10
# 164297 2018.06.28 데이터베이스에 저장 완료!
# 21
# 15006 2000-10-28 데이터베이스에 저장 완료!
# 10
# 172160 2018.06.28 데이터베이스에 저장 완료!
# 10
# 114057 2018.06.28 데이터베이스에 저장 완료!
# 10
# 175322 2018.06.27 데이터베이스에 저장 완료!
# 10
# 167787 2018.06.27 데이터베이스에 저장 완료!
# 10
# 175365 2018.06.27 데이터베이스에 저장 완료!
# 10
# 51548 2018.06.27 데이터베이스에 저장 완료!
# 10
# 152680 2018.06.27 데이터베이스에 저장 완료!
# 10
# 143416 2018.06.21 데이터베이스에 저장 완료!
# 10
# 167064 2018.06.21 데이터베이스에 저장 완료!
# 10
# 162423 2018.06.21 데이터베이스에 저장 완료!
# 10
# 150097 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169240 2018.06.21 데이터베이스에 저장 완료!
# 10
# 146566 2018.06.21 데이터베이스에 저장 완료!
# 10
# 175617 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169647 2018.06.21 데이터베이스에 저장 완료!
# 10
# 163824 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169899 2018.06.21 데이터베이스에 저장 완료!
# 21
# 172005 2018-02-28 데이터베이스에 저장 완료!
# 10
# 151145 2018.06.21 데이터베이스에 저장 완료!
# 10
# 168405 2018.06.20 데이터베이스에 저장 완료!
# 10
# 162854 2018.06.14 데이터베이스에 저장 완료!
# 10
# 163893 2018.06.14 데이터베이스에 저장 완료!
# 10
# 163900 2018.06.14 데이터베이스에 저장 완료!
# 10
# 159892 2018.06.13 데이터베이스에 저장 완료!
# 10
# 153675 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174810 2018.06.13 데이터베이스에 저장 완료!
# 10
# 162014 2018.06.07 데이터베이스에 저장 완료!
# 10
# 172420 2018.06.07 데이터베이스에 저장 완료!
# 10
# 154285 2018.06.06 데이터베이스에 저장 완료!
# 10
# 168017 2018.06.06 데이터베이스에 저장 완료!
# 10
# 174811 2018.06.06 데이터베이스에 저장 완료!
# 10
# 68291 2018.06.06 데이터베이스에 저장 완료!
# 10
# 174804 2018.06.06 데이터베이스에 저장 완료!
# 10
# 152689 2018.05.31 데이터베이스에 저장 완료!
# 10
# 168693 2018.05.30 데이터베이스에 저장 완료!
# 10
# 147388 2018.05.30 데이터베이스에 저장 완료!
# 10
# 167049 2018.05.30 데이터베이스에 저장 완료!
# 10
# 171413 2018.05.24 데이터베이스에 저장 완료!
# 10
# 174257 2018.05.24 데이터베이스에 저장 완료!
# 10
# 165321 2018.05.24 데이터베이스에 저장 완료!
# 10
# 154550 2018.05.24 데이터베이스에 저장 완료!
# 10
# 158178 2018.05.22 데이터베이스에 저장 완료!
# 10
# 164183 2018.05.22 데이터베이스에 저장 완료!
# 10
# 155263 2018.05.17 데이터베이스에 저장 완료!
# 10
# 171414 2018.05.17 데이터베이스에 저장 완료!
# 10
# 159105 2018.05.17 데이터베이스에 저장 완료!
# 10
# 154226 2018.05.16 데이터베이스에 저장 완료!
# 10
# 149236 2018.05.16 데이터베이스에 저장 완료!
# 10
# 170289 2018.05.10 데이터베이스에 저장 완료!
# 10
# 173466 2018.05.03 데이터베이스에 저장 완료!
# 10
# 164684 2018.05.03 데이터베이스에 저장 완료!
# 21
# 164290 2017-06-10 데이터베이스에 저장 완료!
# 10
# 136315 2018.04.25 데이터베이스에 저장 완료!
# 10
# 159827 2018.04.25 데이터베이스에 저장 완료!
# 10
# 142250 2018.04.19 데이터베이스에 저장 완료!
# 10
# 159311 2018.03.22 데이터베이스에 저장 완료!
# 10
# 171440 2018.03.22 데이터베이스에 저장 완료!
# 10
# 171828 2018.01.25 데이터베이스에 저장 완료!
# 21
# 27414 2001-12-08 데이터베이스에 저장 완료!
# 21
# 10173 1990-11-24 데이터베이스에 저장 완료!
# 10
# 166583 2017.12.14 데이터베이스에 저장 완료!
# 10
# 164335 2017.12.07 데이터베이스에 저장 완료!
# 10
# 154458 2017.08.03 데이터베이스에 저장 완료!
# 10
# 162933 2017.06.01 데이터베이스에 저장 완료!
# 10
# 157564 2017.02.22 데이터베이스에 저장 완료!
# 21
# 38546 2005-04-01 데이터베이스에 저장 완료!
# 10
# 155123 2016.11.24 데이터베이스에 저장 완료!
# 10
# 152173 2016.08.17 데이터베이스에 저장 완료!
# 21
# 50749 2009-06-18 데이터베이스에 저장 완료!
# 10
# 146548 2016.07.27 데이터베이스에 저장 완료!
# 10
# 146311 2016.07.14 데이터베이스에 저장 완료!
# 10
# 31368 2016.07.07 데이터베이스에 저장 완료!
# 10
# 145376 2016.02.04 데이터베이스에 저장 완료!
# 10
# 132610 2015.12.17 데이터베이스에 저장 완료!
# 10
# 125466 2015.12.03 데이터베이스에 저장 완료!
# 10
# 119563 2015.02.12 데이터베이스에 저장 완료!
# 10
# 132989 2015.02.05 데이터베이스에 저장 완료!
# 10
# 103719 2013.12.19 데이터베이스에 저장 완료!
# 10
# 85141 2013.03.07 데이터베이스에 저장 완료!
# 10
# 87663 2011.12.22 데이터베이스에 저장 완료!
# 10
# 27267 2002.11.22 데이터베이스에 저장 완료!
# 10
# 18783 1998.01.01 데이터베이스에 저장 완료!
# 10
# 16581 1997.08.23 데이터베이스에 저장 완료!
# 21
# 23971 1958-07-02 데이터베이스에 저장 완료!
# 10
# 10593 1957.04.27 데이터베이스에 저장 완료!
# 현재상영작 저장 완료!
# 10
# 171866 2018.07.09 데이터베이스에 저장 완료!
# 10
# 176537 2018.07.10 데이터베이스에 저장 완료!
# 10
# 160375 2018.07.11 데이터베이스에 저장 완료!
# 10
# 170859 2018.07.11 데이터베이스에 저장 완료!
# 10
# 152694 2018.07.12 데이터베이스에 저장 완료!
# 10
# 144130 2018.07.12 데이터베이스에 저장 완료!
# 10
# 174387 2018.07.12 데이터베이스에 저장 완료!
# 10
# 175229 2018.07.12 데이터베이스에 저장 완료!
# 10
# 169688 2018.07.12 데이터베이스에 저장 완료!
# 10
# 166476 2018.07.12 데이터베이스에 저장 완료!
# 10
# 175614 2018.07.12 데이터베이스에 저장 완료!
# 10
# 161833 2018.07.12 데이터베이스에 저장 완료!
# 10
# 149144 2018.07.12 데이터베이스에 저장 완료!
# 10
# 160992 2018.07.12 데이터베이스에 저장 완료!
# 10
# 98980 2018.07.12 데이터베이스에 저장 완료!
# 10
# 172003 2018.07.13 데이터베이스에 저장 완료!
# 10
# 176524 2018.07.17 데이터베이스에 저장 완료!
# 31
# 84845 2012-08-01 데이터베이스에 저장 완료!
# 10
# 136990 2018.07.18 데이터베이스에 저장 완료!
# 10
# 158890 2018.07.18 데이터베이스에 저장 완료!
# 10
# 167058 2018.07.18 데이터베이스에 저장 완료!
# 10
# 168030 2018.07.18 데이터베이스에 저장 완료!
# 10
# 172344 2018.07.19 데이터베이스에 저장 완료!
# 41
# 17170 1995-02-18 데이터베이스에 저장 완료!
# 10
# 160721 2018.07.19 데이터베이스에 저장 완료!
# 10
# 157340 2018.07.19 데이터베이스에 저장 완료!
# 10
# 172113 2018.07.19 데이터베이스에 저장 완료!
# 10
# 134871 2018.07.19 데이터베이스에 저장 완료!
# 10
# 154222 2018.07.25 데이터베이스에 저장 완료!
# 10
# 174805 2018.07.25 데이터베이스에 저장 완료!
# 10
# 177378 2018.07.25 데이터베이스에 저장 완료!
# 10
# 172174 2018.07.26 데이터베이스에 저장 완료!
# 21
# 71151 2011-01-20 데이터베이스에 저장 완료!
# 10
# 163867 2018.07.26 데이터베이스에 저장 완료!
# 7
# 7
# 7
# 7
# 7
# 7
# 10
# 154223 2018.08.02 데이터베이스에 저장 완료!
# 10
# 173784 2018.08.02 데이터베이스에 저장 완료!
# 21
# 66751 2008-02-21 데이터베이스에 저장 완료!
# 10
# 175317 2018.08.14 데이터베이스에 저장 완료!
# 10
# 159636 2018.08.16 데이터베이스에 저장 완료!
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 상영작 예정작 저장 완료!

# %%
cnnt.initialize()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-5-5d91b915aa85> in <module>()
# ----> 1 cnnt.initialize()
#
# ~/workspace/DB/chatbot_project/Chatbot_Project/connections.py in initialize()
#      60     # delete = '''TRUNCATE TABLE BaseMovieInfo'''
#      61     delete = '''DELETE FROM BaseMovieInfo'''
# ---> 62     curs.execute(delete)
#      63     curs.close()
#      64     curs = mk_cursor()
#
# ~/anaconda3/envs/db/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~/anaconda3/envs/db/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~/anaconda3/envs/db/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     891                 sql = sql.encode(self.encoding, 'surrogateescape')
#     892         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 893         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     894         return self._affected_rows
#     895
#
# ~/anaconda3/envs/db/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1101         else:
#    1102             result = MySQLResult(self)
# -> 1103             result.read()
#    1104         self._result = result
#    1105         if result.server_status is not None:
#
# ~/anaconda3/envs/db/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1394     def read(self):
#    1395         try:
# -> 1396             first_packet = self.connection._read_packet()
#    1397
#    1398             if first_packet.is_ok_packet():
#
# ~/anaconda3/envs/db/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1057
#    1058         packet = packet_type(buff, self.encoding)
# -> 1059         packet.check_error()
#    1060         return packet
#    1061
#
# ~/anaconda3/envs/db/lib/python3.6/site-packages/pymysql/connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# ~/anaconda3/envs/db/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# IntegrityError: (1451, 'Cannot delete or update a parent row: a foreign key constraint fails (`DBtoday`.`ActorsOfMovie`, CONSTRAINT `ActorsOfMovie_ibfk_1` FOREIGN KEY (`movie_code`) REFERENCES `BaseMovieInfo` (`movie_code`))')

# %% [markdown]
# # 관객수그래프 정보 Insert, 그리기, 저장

# %%
flask_bot.insert_trend(30)
flask_bot.insert_trend(14)
flask_bot.insert_trend(7)

# %%
#this is parent module of insert_trend
smd.insert_movie_audiance_num_per_date(datetime.datetime.now().date(), 2)

# %%
def query_and_draw(time):
    today = datetime.datetime.now()
    week = datetime.timedelta(time)
    a_week_ago = (today - week).date()
    print(today.date(), a_week_ago.strftime("%Y-%m-%d"))
    return smd.query_and_draw(today.date(), a_week_ago)

# %%
query_and_draw(7)

# %%
query_and_draw(14)

# %%
query_and_draw(30)

# %%
#
