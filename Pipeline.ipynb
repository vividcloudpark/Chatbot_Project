# %% [markdown]
# # DB Insert 를 위한 모듈들

# %%
import get_information as gi
import connections as cnnt
import show_movie_trend as smd
import flask_bot
import datetime
# Out:
# /home/hyuna/anaconda3/envs/db/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '
# /home/hyuna/anaconda3/envs/db/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %% [markdown]
# # 상영작, 상영예정작 Insert

# %%
to_craw_list_op = gi.make_craw_list("op")
print(to_craw_list_op)
to_craw_list_pre = gi.make_craw_list("pre")
print(to_craw_list_pre)
# Out:
# ['162854', '163893', '163900', '159892', '153675', '174878', '174810', '174809', '172420', '162014', '152669', '159647', '154285', '168017', '68291', '174811', '174804', '152689', '156098', '104390', '173958', '158623', '166482', '147388', '167049', '168693', '81240', '171441', '174257', '171413', '165321', '154550', '143776', '171415', '170206', '144693', '158178', '164183', '155263', '159105', '171414', '162395', '149236', '171822', '154226', '156584', '170289', '172034', '165020', '164684', '154251', '169347', '164290', '136315', '157243', '159827', '173459', '162715', '142250', '10230', '173653', '150658', '159311', '171440', '155567', '164719', '153936', '171828', '162869', '106360', '164979', '164335', '156912', '144379', '99093', '158910', '162933', '154112', '153621', '155123', '152173', '145376', '67786', '132989', '10593', '106027', '30012']
# ['168405', '150097', '167064', '90965', '146566', '162423', '163824', '169899', '143416', '151145', '62266', '169647', '169240', '175617', '163682', '167787', '51548', '175322', '175365', '152680', '162098', '164297', '149049', '168303', '15006', '137688', '175320', '171501', '174798', '144785', '166476', '164151', '144330', '175325', '140285', '17170', '170859', '175614', '172344', '172113', '154222', '172174', '140288', '164115', '161833', '158890', '172003', '160375', '174805', '109906', '136990', '159839', '162265', '168030', '167697', '175727', '164916', '152661', '169015', '169643', '174807', '152156', '132996', '119428', '154255', '150688', '156496', '171725', '109193', '154672']

# %%
for i in range(len(to_craw_list_op)):
    gi.get_by_moviecode(to_craw_list_op[i])
print("현재상영작 저장 완료!")

for i in range(len(to_craw_list_pre)):
    gi.get_by_moviecode(to_craw_list_pre[i])
print("상영작 예정작 저장 완료!")
# Out:
# 10
# 162854 2018.06.14 데이터베이스에 저장 완료!
# 10
# 163893 2018.06.14 데이터베이스에 저장 완료!
# 10
# 163900 2018.06.14 데이터베이스에 저장 완료!
# 10
# 159892 2018.06.13 데이터베이스에 저장 완료!
# 10
# 153675 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174878 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174810 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174809 2018.06.13 데이터베이스에 저장 완료!
# 10
# 172420 2018.06.07 데이터베이스에 저장 완료!
# 10
# 162014 2018.06.07 데이터베이스에 저장 완료!
# 10
# 152669 2018.06.07 데이터베이스에 저장 완료!
# 10
# 159647 2018.06.07 데이터베이스에 저장 완료!
# 10
# 154285 2018.06.06 데이터베이스에 저장 완료!
# 10
# 168017 2018.06.06 데이터베이스에 저장 완료!
# 10
# 68291 2018.06.06 데이터베이스에 저장 완료!
# 10
# 174811 2018.06.06 데이터베이스에 저장 완료!
# 10
# 174804 2018.06.06 데이터베이스에 저장 완료!
# 10
# 152689 2018.05.31 데이터베이스에 저장 완료!
# 10
# 156098 2018.05.31 데이터베이스에 저장 완료!
# 10
# 104390 2018.05.31 데이터베이스에 저장 완료!
# 10
# 173958 2018.05.31 데이터베이스에 저장 완료!
# 10
# 158623 2018.05.31 데이터베이스에 저장 완료!
# 10
# 166482 2018.05.31 데이터베이스에 저장 완료!
# 10
# 147388 2018.05.30 데이터베이스에 저장 완료!
# 10
# 167049 2018.05.30 데이터베이스에 저장 완료!
# 10
# 168693 2018.05.30 데이터베이스에 저장 완료!
# 10
# 81240 2018.05.30 데이터베이스에 저장 완료!
# 10
# 171441 2018.05.30 데이터베이스에 저장 완료!
# 10
# 174257 2018.05.24 데이터베이스에 저장 완료!
# 10
# 171413 2018.05.24 데이터베이스에 저장 완료!
# 10
# 165321 2018.05.24 데이터베이스에 저장 완료!
# 10
# 154550 2018.05.24 데이터베이스에 저장 완료!
# 10
# 143776 2018.05.24 데이터베이스에 저장 완료!
# 10
# 171415 2018.05.24 데이터베이스에 저장 완료!
# 10
# 170206 2018.05.24 데이터베이스에 저장 완료!
# 10
# 144693 2018.05.24 데이터베이스에 저장 완료!
# 10
# 158178 2018.05.22 데이터베이스에 저장 완료!
# 10
# 164183 2018.05.22 데이터베이스에 저장 완료!
# 10
# 155263 2018.05.17 데이터베이스에 저장 완료!
# 10
# 159105 2018.05.17 데이터베이스에 저장 완료!
# 10
# 171414 2018.05.17 데이터베이스에 저장 완료!
# 10
# 162395 2018.05.17 데이터베이스에 저장 완료!
# 10
# 149236 2018.05.16 데이터베이스에 저장 완료!
# 10
# 171822 2018.05.16 데이터베이스에 저장 완료!
# 10
# 154226 2018.05.16 데이터베이스에 저장 완료!
# 10
# 156584 2018.05.10 데이터베이스에 저장 완료!
# 10
# 170289 2018.05.10 데이터베이스에 저장 완료!
# 10
# 172034 2018.05.10 데이터베이스에 저장 완료!
# 10
# 165020 2018.05.09 데이터베이스에 저장 완료!
# 10
# 164684 2018.05.03 데이터베이스에 저장 완료!
# 10
# 154251 2018.05.03 데이터베이스에 저장 완료!
# 10
# 169347 2018.05.01 데이터베이스에 저장 완료!
# 21
# 164290 2017-06-10 데이터베이스에 저장 완료!
# 10
# 136315 2018.04.25 데이터베이스에 저장 완료!
# 10
# 157243 2018.04.25 데이터베이스에 저장 완료!
# 10
# 159827 2018.04.25 데이터베이스에 저장 완료!
# 10
# 173459 2018.04.19 데이터베이스에 저장 완료!
# 10
# 162715 2018.04.19 데이터베이스에 저장 완료!
# 10
# 142250 2018.04.19 데이터베이스에 저장 완료!
# 28
# 10
# 173653 2018.04.12 데이터베이스에 저장 완료!
# 10
# 150658 2018.03.28 데이터베이스에 저장 완료!
# 10
# 159311 2018.03.22 데이터베이스에 저장 완료!
# 10
# 171440 2018.03.22 데이터베이스에 저장 완료!
# 10
# 155567 2018.03.08 데이터베이스에 저장 완료!
# 10
# 164719 2018.03.07 데이터베이스에 저장 완료!
# 10
# 153936 2018.01.25 데이터베이스에 저장 완료!
# 10
# 171828 2018.01.25 데이터베이스에 저장 완료!
# 10
# 162869 2017.12.28 데이터베이스에 저장 완료!
# 10
# 106360 2017.12.20 데이터베이스에 저장 완료!
# 10
# 164979 2017.12.14 데이터베이스에 저장 완료!
# 10
# 164335 2017.12.07 데이터베이스에 저장 완료!
# 10
# 156912 2017.12.07 데이터베이스에 저장 완료!
# 10
# 144379 2017.11.09 데이터베이스에 저장 완료!
# 10
# 99093 2017.11.09 데이터베이스에 저장 완료!
# 10
# 158910 2017.07.13 데이터베이스에 저장 완료!
# 10
# 162933 2017.06.01 데이터베이스에 저장 완료!
# 10
# 154112 2017.05.17 데이터베이스에 저장 완료!
# 10
# 153621 2017.04.13 데이터베이스에 저장 완료!
# 10
# 155123 2016.11.24 데이터베이스에 저장 완료!
# 10
# 152173 2016.08.17 데이터베이스에 저장 완료!
# 10
# 145376 2016.02.04 데이터베이스에 저장 완료!
# 10
# 67786 2015.06.11 데이터베이스에 저장 완료!
# 10
# 132989 2015.02.05 데이터베이스에 저장 완료!
# 10
# 10593 1957.04.27 데이터베이스에 저장 완료!
# 10
# 106027 1957.01.01 데이터베이스에 저장 완료!
# 10
# 30012 1955.11.15 데이터베이스에 저장 완료!
# 현재상영작 저장 완료!
# 10
# 168405 2018.06.20 데이터베이스에 저장 완료!
# 10
# 150097 2018.06.21 데이터베이스에 저장 완료!
# 10
# 167064 2018.06.21 데이터베이스에 저장 완료!
# 10
# 90965 2018.06.21 데이터베이스에 저장 완료!
# 10
# 146566 2018.06.21 데이터베이스에 저장 완료!
# 10
# 162423 2018.06.21 데이터베이스에 저장 완료!
# 10
# 163824 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169899 2018.06.21 데이터베이스에 저장 완료!
# 10
# 143416 2018.06.21 데이터베이스에 저장 완료!
# 10
# 151145 2018.06.21 데이터베이스에 저장 완료!
# 31
# 62266 2009-12-17 데이터베이스에 저장 완료!
# 10
# 169647 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169240 2018.06.21 데이터베이스에 저장 완료!
# 10
# 175617 2018.06.21 데이터베이스에 저장 완료!
# 10
# 163682 2018.06.21 데이터베이스에 저장 완료!
# 10
# 167787 2018.06.27 데이터베이스에 저장 완료!
# 10
# 51548 2018.06.27 데이터베이스에 저장 완료!
# 10
# 175322 2018.06.27 데이터베이스에 저장 완료!
# 10
# 175365 2018.06.27 데이터베이스에 저장 완료!
# 10
# 152680 2018.06.27 데이터베이스에 저장 완료!
# 10
# 162098 2018.06.28 데이터베이스에 저장 완료!
# 10
# 164297 2018.06.28 데이터베이스에 저장 완료!
# 21
# 149049 2016-08-03 데이터베이스에 저장 완료!
# 10
# 168303 2018.06.28 데이터베이스에 저장 완료!
# 21
# 15006 2000-10-28 데이터베이스에 저장 완료!
# 7
# 7
# 7
# 7
# 7
# 7
# 10
# 164151 2018.07.04 데이터베이스에 저장 완료!
# 10
# 175325 2018.07.05 데이터베이스에 저장 완료!
# 10
# 140285 2018.07.05 데이터베이스에 저장 완료!
# 41
# 17170 1995-02-18 데이터베이스에 저장 완료!
# 10
# 170859 2018.07.11 데이터베이스에 저장 완료!
# 10
# 175614 2018.07.12 데이터베이스에 저장 완료!
# 10
# 172344 2018.07.19 데이터베이스에 저장 완료!
# 10
# 172113 2018.07.19 데이터베이스에 저장 완료!
# 10
# 172174 2018.07.26 데이터베이스에 저장 완료!
# 7
# 7
# 7
# 7
# 7
# 7
# 상영작 예정작 저장 완료!

# %%
cnnt.initialize()
# Out:
# 초기화완료!

# %% [markdown]
# # 관객수그래프 정보 Insert, 그리기, 저장

# %%
flask_bot.insert_trend(30)
flask_bot.insert_trend(14)
flask_bot.insert_trend(7)
# Out:
# value 쥬라기 월드: 폴른 킹덤 20180613 3999925 Inserted
# value 탐정: 리턴즈 20180613 251067 Inserted
# value 오션스8 20180613 200188 Inserted
# value 독전 20180613 4678423 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180613 155195 Inserted
# value 아이 필 프리티 20180613 147074 Inserted
# value 유전 20180613 126936 Inserted
# value 토니스토리2: 고철왕국의 친구들 20180613 6441 Inserted
# value 데드풀 2 20180613 3770915 Inserted
# value 벅스 프렌즈 20180613 30713 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180612 3553116 Inserted
# value 독전 20180612 4619752 Inserted
# value 유전 20180612 119164 Inserted
# value 아이 필 프리티 20180612 132514 Inserted
# value 데드풀 2 20180612 3768278 Inserted
# value 허스토리 20180612 8435 Inserted
# value 탐정: 리턴즈 20180612 15947 Inserted
# value 어벤져스: 인피니티 워 20180612 11181283 Inserted
# value 아바타 20180612 13304452 Inserted
# value 버닝 20180612 523720 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180611 3367500 Inserted
# value 독전 20180611 4557999 Inserted
# value 아이 필 프리티 20180611 117702 Inserted
# value 유전 20180611 101759 Inserted
# value 데드풀 2 20180611 3760060 Inserted
# value 탐정: 리턴즈 20180611 13160 Inserted
# value 허스토리 20180611 3877 Inserted
# value 어벤져스: 인피니티 워 20180611 11179012 Inserted
# value 여중생A 20180611 1630 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180611 135039 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180610 3223510 Inserted
# value 독전 20180610 4505110 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180610 133993 Inserted
# value 아이 필 프리티 20180610 106456 Inserted
# value 유전 20180610 90525 Inserted
# value 데드풀 2 20180610 3753496 Inserted
# value 벅스 프렌즈 20180610 27390 Inserted
# value 어벤져스: 인피니티 워 20180610 11177058 Inserted
# value 피터 래빗 20180610 381571 Inserted
# value 호비와 매직 아일랜드 20180610 9216 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180609 2519855 Inserted
# value 독전 20180609 4356997 Inserted
# value 아이 필 프리티 20180609 80849 Inserted
# value 유전 20180609 66893 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180609 107701 Inserted
# value 데드풀 2 20180609 3741015 Inserted
# value 벅스 프렌즈 20180609 21334 Inserted
# value 어벤져스: 인피니티 워 20180609 11173483 Inserted
# value 피터 래빗 20180609 378398 Inserted
# value 버닝 20180609 519841 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180608 1728506 Inserted
# value 독전 20180608 4188143 Inserted
# value 유전 20180608 38845 Inserted
# value 아이 필 프리티 20180608 52575 Inserted
# value 데드풀 2 20180608 3725186 Inserted
# value 어벤져스: 인피니티 워 20180608 11169421 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180608 82978 Inserted
# value 버닝 20180608 517715 Inserted
# value 오션스8 20180608 4731 Inserted
# value 미드나잇 선 20180608 1123 Inserted
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# value 독전 20180525 922929 Inserted
# value 데드풀 2 20180525 2834881 Inserted
# value 트루스 오어 데어 20180525 110337 Inserted
# value 한 솔로: 스타워즈 스토리 20180525 40562 Inserted
# value 어벤져스: 인피니티 워 20180525 10925181 Inserted
# value 버닝 20180525 413657 Inserted
# value 안녕, 나의 소녀 20180525 81844 Inserted
# value 피터 래빗 20180525 237843 Inserted
# value 레슬러 20180525 762325 Inserted
# value 챔피언 20180525 1124651 Inserted
# value 독전 20180524 703365 Inserted
# value 데드풀 2 20180524 2739773 Inserted
# value 한 솔로: 스타워즈 스토리 20180524 20250 Inserted
# value 트루스 오어 데어 20180524 87332 Inserted
# value 어벤져스: 인피니티 워 20180524 10906136 Inserted
# value 버닝 20180524 399977 Inserted
# value 레슬러 20180524 760752 Inserted
# value 안녕, 나의 소녀 20180524 78422 Inserted
# value 피터 래빗 20180524 235241 Inserted
# value 세라비, 이것이 인생! 20180524 2079 Inserted
# value 독전 20180523 544796 Inserted
# value 데드풀 2 20180523 2664326 Inserted
# value 어벤져스: 인피니티 워 20180523 10891790 Inserted
# value 트루스 오어 데어 20180523 72413 Inserted
# value 버닝 20180523 388043 Inserted
# value 안녕, 나의 소녀 20180523 75712 Inserted
# value 피터 래빗 20180523 233387 Inserted
# value 레슬러 20180523 755694 Inserted
# value 부르고뉴, 와인에서 찾은 인생 20180523 43795 Inserted
# value 무문관 20180523 18765 Inserted
# value 독전 20180522 383650 Inserted
# value 데드풀 2 20180522 2572547 Inserted
# value 어벤져스: 인피니티 워 20180522 10873577 Inserted
# value 피터 래빗 20180522 230480 Inserted
# value 트루스 오어 데어 20180522 55111 Inserted
# value 버닝 20180522 371626 Inserted
# value 안녕, 나의 소녀 20180522 71836 Inserted
# value 레슬러 20180522 753892 Inserted
# value 다이노 헌터: 티렉스VS파키리노 대격돌 20180522 16214 Inserted
# value 마징가 Z: 인피니티 20180522 19397 Inserted
# value 데드풀 2 20180521 2255051 Inserted
# value 어벤져스: 인피니티 워 20180521 10782699 Inserted
# value 버닝 20180521 329290 Inserted
# value 피터 래빗 20180521 150346 Inserted
# value 레슬러 20180521 746256 Inserted
# value 안녕, 나의 소녀 20180521 60018 Inserted
# value 챔피언 20180521 1121004 Inserted
# value 독전 20180521 7117 Inserted
# value 마징가 Z: 인피니티 20180521 16325 Inserted
# value 다이노 헌터: 티렉스VS파키리노 대격돌 20180521 11022 Inserted
# value 데드풀 2 20180520 1973351 Inserted
# value 어벤져스: 인피니티 워 20180520 10690072 Inserted
# value 버닝 20180520 277893 Inserted
# value 피터 래빗 20180520 112487 Inserted
# value 레슬러 20180520 724546 Inserted
# value 안녕, 나의 소녀 20180520 48835 Inserted
# value 마징가 Z: 인피니티 20180520 13924 Inserted
# value 다이노 헌터: 티렉스VS파키리노 대격돌 20180520 8838 Inserted
# value 챔피언 20180520 1117551 Inserted
# value 당갈 20180520 97632 Inserted
# value 데드풀 2 20180519 1511233 Inserted
# value 어벤져스: 인피니티 워 20180519 10574281 Inserted
# value 버닝 20180519 203168 Inserted
# value 피터 래빗 20180519 61794 Inserted
# value 레슬러 20180519 697501 Inserted
# value 안녕, 나의 소녀 20180519 35217 Inserted
# value 마징가 Z: 인피니티 20180519 8602 Inserted
# value 다이노 헌터: 티렉스VS파키리노 대격돌 20180519 4850 Inserted
# value 챔피언 20180519 1114032 Inserted
# value 부르고뉴, 와인에서 찾은 인생 20180519 35857 Inserted
# value 데드풀 2 20180518 940884 Inserted
# value 버닝 20180518 118147 Inserted
# value 어벤져스: 인피니티 워 20180518 10445555 Inserted
# value 레슬러 20180518 668008 Inserted
# value 안녕, 나의 소녀 20180518 21337 Inserted
# value 피터 래빗 20180518 14880 Inserted
# value 챔피언 20180518 1110134 Inserted
# value 5.18 힌츠페터 스토리 20180518 7100 Inserted
# value 임을 위한 행진곡 20180518 11054 Inserted
# value 부르고뉴, 와인에서 찾은 인생 20180518 33464 Inserted
# value 데드풀 2 20180517 617732 Inserted
# value 버닝 20180517 57189 Inserted
# value 어벤져스: 인피니티 워 20180517 10386143 Inserted
# value 레슬러 20180517 646060 Inserted
# value 안녕, 나의 소녀 20180517 11939 Inserted
# value 피터 래빗 20180517 10090 Inserted
# value 챔피언 20180517 1106320 Inserted
# value 독전 20180517 3487 Inserted
# value 마징가 Z: 인피니티 20180517 2483 Inserted
# value 임을 위한 행진곡 20180517 9128 Inserted
# value 데드풀 2 20180516 357947 Inserted
# value 어벤져스: 인피니티 워 20180516 10344994 Inserted
# value 레슬러 20180516 627744 Inserted
# value 챔피언 20180516 1102725 Inserted
# value 안녕, 나의 소녀 20180516 5379 Inserted
# value 피터 래빗 20180516 5837 Inserted
# value 임을 위한 행진곡 20180516 7834 Inserted
# value 당갈 20180516 90801 Inserted
# value 부르고뉴, 와인에서 찾은 인생 20180516 30580 Inserted
# value 루비 스팍스 20180516 23967 Inserted
# No handles with labels found to put in legend.
# image saved
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# No handles with labels found to put in legend.
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# image saved
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# No handles with labels found to put in legend.
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# image saved

# %%
#this is parent module of insert_trend
smd.insert_movie_audiance_num_per_date(datetime.datetime.now().date(), 2)
# Out:
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists

# %%
def query_and_draw(time):
    today = datetime.datetime.now()
    week = datetime.timedelta(time)
    a_week_ago = (today - week).date()
    print(today.date(), a_week_ago.strftime("%Y-%m-%d"))
    return smd.query_and_draw(today.date(), a_week_ago)

# %%
query_and_draw(7)
# Out:
# 2018-06-14 2018-06-07
# image saved

# %%
query_and_draw(14)
# Out:
# 2018-06-14 2018-05-31
# image saved

# %%
query_and_draw(30)
# Out:
# 2018-06-14 2018-05-15
# image saved
