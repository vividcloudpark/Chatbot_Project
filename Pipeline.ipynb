# %% [markdown]
# # DB Insert 를 위한 모듈들

# %%
import get_information as gi
import connections as cnnt
import show_movie_trend as smd
import flask_bot
import datetime
# Out:
# /home/hyuna/anaconda3/envs/db/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '
# /home/hyuna/anaconda3/envs/db/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %% [markdown]
# # 상영작, 상영예정작 Insert

# %%
to_craw_list_op = gi.make_craw_list("op")
print(to_craw_list_op)
to_craw_list_pre = gi.make_craw_list("pre")
print(to_craw_list_pre)
# Out:
# ['168303', '164297', '162098', '170267', '172160', '114057', '15006', '175322', '167787', '175365', '51548', '152680', '143416', '167064', '150097', '162423', '169240', '146566', '175617', '163824', '169899', '151145', '169647', '90965', '172005', '163682', '168405', '162854', '163893', '163900', '159892', '153675', '174810', '174878', '172420', '162014', '154285', '168017', '174811', '68291', '174804', '152689', '104390', '147388', '168693', '167049', '174257', '171413', '154550', '165321', '143776', '158178', '164183', '155263', '171414', '159105', '149236', '154226', '170289', '156584', '173466', '162874', '164290', '136315', '159827', '142250', '144806', '159311', '171440', '27414', '10173', '164979', '166583', '164335', '154458', '162933', '157564', '38546', '155123', '152173', '50749', '146548', '146311', '31368', '145376', '132610', '92064', '119563', '132989', '103719', '87663', '27267', '18783', '16581', '23971', '10431', '10593', '13481']
# ['144330', '164151', '175325', '159839', '163749', '140285', '175248', '175241', '175236', '163734', '174393', '171866', '160375', '170859', '17170', '175614', '161833', '144130', '149144', '160992', '169688', '152694', '166476', '172003', '158890', '168030', '167058', '160721', '172344', '157340', '172113', '136990', '134871', '154222', '174805', '109906', '71151', '172174', '163867', '173581', '162265', '174798', '171764', '154027', '167558', '167697', '153687', '164115', '66751', '175317', '172118', '175727', '140652', '164916', '152661', '173019', '169015', '169643', '174807', '152156', '162870', '174301', '176988', '132996', '119428', '168058', '154255', '150688', '156496', '171725', '109193', '154672']

# %%
for i in range(len(to_craw_list_op)):
    gi.get_by_moviecode(to_craw_list_op[i])
print("현재상영작 저장 완료!")

for i in range(len(to_craw_list_pre)):
    gi.get_by_moviecode(to_craw_list_pre[i])
print("상영작 예정작 저장 완료!")
# Out:
# 10
# 168303 2018.06.28 데이터베이스에 저장 완료!
# 10
# 164297 2018.06.28 데이터베이스에 저장 완료!
# 10
# 162098 2018.06.28 데이터베이스에 저장 완료!
# 10
# 170267 2018.06.28 데이터베이스에 저장 완료!
# 10
# 172160 2018.06.28 데이터베이스에 저장 완료!
# 10
# 114057 2018.06.28 데이터베이스에 저장 완료!
# 21
# 15006 2000-10-28 데이터베이스에 저장 완료!
# 10
# 175322 2018.06.27 데이터베이스에 저장 완료!
# 10
# 167787 2018.06.27 데이터베이스에 저장 완료!
# 10
# 175365 2018.06.27 데이터베이스에 저장 완료!
# 10
# 51548 2018.06.27 데이터베이스에 저장 완료!
# 10
# 152680 2018.06.27 데이터베이스에 저장 완료!
# 10
# 143416 2018.06.21 데이터베이스에 저장 완료!
# 10
# 167064 2018.06.21 데이터베이스에 저장 완료!
# 10
# 150097 2018.06.21 데이터베이스에 저장 완료!
# 10
# 162423 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169240 2018.06.21 데이터베이스에 저장 완료!
# 10
# 146566 2018.06.21 데이터베이스에 저장 완료!
# 10
# 175617 2018.06.21 데이터베이스에 저장 완료!
# 10
# 163824 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169899 2018.06.21 데이터베이스에 저장 완료!
# 10
# 151145 2018.06.21 데이터베이스에 저장 완료!
# 10
# 169647 2018.06.21 데이터베이스에 저장 완료!
# 10
# 90965 2018.06.21 데이터베이스에 저장 완료!
# 21
# 172005 2018-02-28 데이터베이스에 저장 완료!
# 10
# 163682 2018.06.21 데이터베이스에 저장 완료!
# 10
# 168405 2018.06.20 데이터베이스에 저장 완료!
# 10
# 162854 2018.06.14 데이터베이스에 저장 완료!
# 10
# 163893 2018.06.14 데이터베이스에 저장 완료!
# 10
# 163900 2018.06.14 데이터베이스에 저장 완료!
# 10
# 159892 2018.06.13 데이터베이스에 저장 완료!
# 10
# 153675 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174810 2018.06.13 데이터베이스에 저장 완료!
# 10
# 174878 2018.06.13 데이터베이스에 저장 완료!
# 10
# 172420 2018.06.07 데이터베이스에 저장 완료!
# 10
# 162014 2018.06.07 데이터베이스에 저장 완료!
# 10
# 154285 2018.06.06 데이터베이스에 저장 완료!
# 10
# 168017 2018.06.06 데이터베이스에 저장 완료!
# 10
# 174811 2018.06.06 데이터베이스에 저장 완료!
# 10
# 68291 2018.06.06 데이터베이스에 저장 완료!
# 10
# 174804 2018.06.06 데이터베이스에 저장 완료!
# 10
# 152689 2018.05.31 데이터베이스에 저장 완료!
# 10
# 104390 2018.05.31 데이터베이스에 저장 완료!
# 10
# 147388 2018.05.30 데이터베이스에 저장 완료!
# 10
# 168693 2018.05.30 데이터베이스에 저장 완료!
# 10
# 167049 2018.05.30 데이터베이스에 저장 완료!
# 10
# 174257 2018.05.24 데이터베이스에 저장 완료!
# 10
# 171413 2018.05.24 데이터베이스에 저장 완료!
# 10
# 154550 2018.05.24 데이터베이스에 저장 완료!
# 10
# 165321 2018.05.24 데이터베이스에 저장 완료!
# 10
# 143776 2018.05.24 데이터베이스에 저장 완료!
# 10
# 158178 2018.05.22 데이터베이스에 저장 완료!
# 10
# 164183 2018.05.22 데이터베이스에 저장 완료!
# 10
# 155263 2018.05.17 데이터베이스에 저장 완료!
# 10
# 171414 2018.05.17 데이터베이스에 저장 완료!
# 10
# 159105 2018.05.17 데이터베이스에 저장 완료!
# 10
# 149236 2018.05.16 데이터베이스에 저장 완료!
# 10
# 154226 2018.05.16 데이터베이스에 저장 완료!
# 10
# 170289 2018.05.10 데이터베이스에 저장 완료!
# 10
# 156584 2018.05.10 데이터베이스에 저장 완료!
# 10
# 173466 2018.05.03 데이터베이스에 저장 완료!
# 10
# 162874 2018.05.03 데이터베이스에 저장 완료!
# 21
# 164290 2017-06-10 데이터베이스에 저장 완료!
# 10
# 136315 2018.04.25 데이터베이스에 저장 완료!
# 10
# 159827 2018.04.25 데이터베이스에 저장 완료!
# 10
# 142250 2018.04.19 데이터베이스에 저장 완료!
# 10
# 144806 2018.04.05 데이터베이스에 저장 완료!
# 10
# 159311 2018.03.22 데이터베이스에 저장 완료!
# 10
# 171440 2018.03.22 데이터베이스에 저장 완료!
# 21
# 27414 2001-12-08 데이터베이스에 저장 완료!
# 21
# 10173 1990-11-24 데이터베이스에 저장 완료!
# 10
# 164979 2017.12.14 데이터베이스에 저장 완료!
# 10
# 166583 2017.12.14 데이터베이스에 저장 완료!
# 10
# 164335 2017.12.07 데이터베이스에 저장 완료!
# 10
# 154458 2017.08.03 데이터베이스에 저장 완료!
# 10
# 162933 2017.06.01 데이터베이스에 저장 완료!
# 10
# 157564 2017.02.22 데이터베이스에 저장 완료!
# 21
# 38546 2005-04-01 데이터베이스에 저장 완료!
# 10
# 155123 2016.11.24 데이터베이스에 저장 완료!
# 10
# 152173 2016.08.17 데이터베이스에 저장 완료!
# 21
# 50749 2009-06-18 데이터베이스에 저장 완료!
# 10
# 146548 2016.07.27 데이터베이스에 저장 완료!
# 10
# 146311 2016.07.14 데이터베이스에 저장 완료!
# 10
# 31368 2016.07.07 데이터베이스에 저장 완료!
# 10
# 145376 2016.02.04 데이터베이스에 저장 완료!
# 10
# 132610 2015.12.17 데이터베이스에 저장 완료!
# 10
# 92064 2015.09.03 데이터베이스에 저장 완료!
# 10
# 119563 2015.02.12 데이터베이스에 저장 완료!
# 10
# 132989 2015.02.05 데이터베이스에 저장 완료!
# 10
# 103719 2013.12.19 데이터베이스에 저장 완료!
# 10
# 87663 2011.12.22 데이터베이스에 저장 완료!
# 10
# 27267 2002.11.22 데이터베이스에 저장 완료!
# 10
# 18783 1998.01.01 데이터베이스에 저장 완료!
# 10
# 16581 1997.08.23 데이터베이스에 저장 완료!
# 21
# 23971 1958-07-02 데이터베이스에 저장 완료!
# 10
# 10431 1966.07.03 데이터베이스에 저장 완료!
# 10
# 10593 1957.04.27 데이터베이스에 저장 완료!
# 현재상영작 저장 완료!
# 10
# 144330 2018.07.04 데이터베이스에 저장 완료!
# 10
# 164151 2018.07.04 데이터베이스에 저장 완료!
# 10
# 175325 2018.07.05 데이터베이스에 저장 완료!
# 10
# 159839 2018.07.05 데이터베이스에 저장 완료!
# 10
# 163749 2018.07.05 데이터베이스에 저장 완료!
# 10
# 140285 2018.07.05 데이터베이스에 저장 완료!
# 10
# 175248 2018.07.05 데이터베이스에 저장 완료!
# 10
# 175241 2018.07.05 데이터베이스에 저장 완료!
# 10
# 175236 2018.07.05 데이터베이스에 저장 완료!
# 10
# 163734 2018.07.05 데이터베이스에 저장 완료!
# 10
# 174393 2018.07.06 데이터베이스에 저장 완료!
# 10
# 171866 2018.07.09 데이터베이스에 저장 완료!
# 10
# 160375 2018.07.11 데이터베이스에 저장 완료!
# 10
# 170859 2018.07.11 데이터베이스에 저장 완료!
# 41
# 17170 1995-02-18 데이터베이스에 저장 완료!
# 10
# 175614 2018.07.12 데이터베이스에 저장 완료!
# 10
# 161833 2018.07.12 데이터베이스에 저장 완료!
# 10
# 144130 2018.07.12 데이터베이스에 저장 완료!
# 10
# 149144 2018.07.12 데이터베이스에 저장 완료!
# 10
# 160992 2018.07.12 데이터베이스에 저장 완료!
# 10
# 169688 2018.07.12 데이터베이스에 저장 완료!
# 10
# 152694 2018.07.12 데이터베이스에 저장 완료!
# 10
# 166476 2018.07.12 데이터베이스에 저장 완료!
# 10
# 172003 2018.07.13 데이터베이스에 저장 완료!
# 10
# 158890 2018.07.18 데이터베이스에 저장 완료!
# 10
# 168030 2018.07.18 데이터베이스에 저장 완료!
# 10
# 167058 2018.07.19 데이터베이스에 저장 완료!
# 10
# 160721 2018.07.19 데이터베이스에 저장 완료!
# 10
# 172344 2018.07.19 데이터베이스에 저장 완료!
# 10
# 157340 2018.07.19 데이터베이스에 저장 완료!
# 10
# 172113 2018.07.19 데이터베이스에 저장 완료!
# 10
# 136990 2018.07.19 데이터베이스에 저장 완료!
# 10
# 134871 2018.07.19 데이터베이스에 저장 완료!
# 10
# 154222 2018.07.25 데이터베이스에 저장 완료!
# 21
# 71151 2011-01-20 데이터베이스에 저장 완료!
# 10
# 172174 2018.07.26 데이터베이스에 저장 완료!
# 10
# 163867 2018.07.26 데이터베이스에 저장 완료!
# 7
# 7
# 7
# 7
# 7
# 7
# 21
# 66751 2008-02-21 데이터베이스에 저장 완료!
# 10
# 175317 2018.08.14 데이터베이스에 저장 완료!
# 7
# 7
# 7
# 7
# 7
# 7
# 상영작 예정작 저장 완료!

# %%
cnnt.initialize()

# %% [markdown]
# # 관객수그래프 정보 Insert, 그리기, 저장

# %%
flask_bot.insert_trend(30)
flask_bot.insert_trend(14)
flask_bot.insert_trend(7)
# Out:
# value 탐정: 리턴즈 20180621 101540 Inserted
# value 오션스8 20180621 48002 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180621 47086 Inserted
# value 독전 20180621 14174 Inserted
# value 미드나잇 선 20180621 12067 Inserted
# value 허스토리 20180621 8769 Inserted
# value 여중생A 20180621 5871 Inserted
# value 아일라 20180621 3970 Inserted
# value 아이 필 프리티 20180621 3848 Inserted
# value 아바타 20180621 3296 Inserted
# value 탐정: 리턴즈 20180620 105026 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180620 53854 Inserted
# value 오션스8 20180620 51477 Inserted
# value 독전 20180620 17470 Inserted
# value 여중생A 20180620 11085 Inserted
# value 아이 필 프리티 20180620 4056 Inserted
# value 변산 20180620 3068 Inserted
# value 마녀 20180620 3012 Inserted
# value 유전 20180620 2660 Inserted
# value 허스토리 20180620 1180 Inserted
# value 탐정: 리턴즈 20180619 95046 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180619 49082 Inserted
# value 오션스8 20180619 46808 Inserted
# value 독전 20180619 17972 Inserted
# value 아이 필 프리티 20180619 4520 Inserted
# value 아일라 20180619 2964 Inserted
# value 여중생A 20180619 2871 Inserted
# value 유전 20180619 2842 Inserted
# value 허스토리 20180619 2341 Inserted
# value 미드나잇 선 20180619 2116 Inserted
# value 탐정: 리턴즈 20180618 73775 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180618 44955 Inserted
# value 오션스8 20180618 38215 Inserted
# value 독전 20180618 15514 Inserted
# value 아이 필 프리티 20180618 3826 Inserted
# value 유전 20180618 2879 Inserted
# value 변산 20180618 1519 Inserted
# value 여중생A 20180618 1376 Inserted
# value 허스토리 20180618 1111 Inserted
# value 데드풀 2 20180618 760 Inserted
# value 탐정: 리턴즈 20180617 271088 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180617 256882 Inserted
# value 오션스8 20180617 120188 Inserted
# value 독전 20180617 46614 Inserted
# value 아이 필 프리티 20180617 9457 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180617 9307 Inserted
# value 유전 20180617 5642 Inserted
# value 토니스토리2: 고철왕국의 친구들 20180617 2540 Inserted
# value 데드풀 2 20180617 1772 Inserted
# value 바르다가 사랑한 얼굴들 20180617 1581 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180616 298151 Inserted
# value 탐정: 리턴즈 20180616 288708 Inserted
# value 오션스8 20180616 150550 Inserted
# value 독전 20180616 53825 Inserted
# value 아이 필 프리티 20180616 11211 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180616 8018 Inserted
# value 유전 20180616 7548 Inserted
# value 토니스토리2: 고철왕국의 친구들 20180616 2338 Inserted
# value 데드풀 2 20180616 2136 Inserted
# value 바르다가 사랑한 얼굴들 20180616 1729 Inserted
# value 탐정: 리턴즈 20180615 127009 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180615 112582 Inserted
# value 오션스8 20180615 84344 Inserted
# value 독전 20180615 26266 Inserted
# value 아이 필 프리티 20180615 6521 Inserted
# value 유전 20180615 4766 Inserted
# value 데드풀 2 20180615 1668 Inserted
# value 더 펜션 20180615 1131 Inserted
# value 바르다가 사랑한 얼굴들 20180615 1028 Inserted
# value 류이치 사카모토: 코다 20180615 874 Inserted
# value 탐정: 리턴즈 20180614 92257 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180614 85201 Inserted
# value 오션스8 20180614 65616 Inserted
# value 독전 20180614 21751 Inserted
# value 아이 필 프리티 20180614 5203 Inserted
# value 유전 20180614 3389 Inserted
# value 허스토리 20180614 2975 Inserted
# value 변산 20180614 2080 Inserted
# value 미드나잇 선 20180614 1674 Inserted
# value 데드풀 2 20180614 1246 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180613 446891 Inserted
# value 탐정: 리턴즈 20180613 235195 Inserted
# value 오션스8 20180613 195524 Inserted
# value 독전 20180613 58713 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180613 19091 Inserted
# value 아이 필 프리티 20180613 14597 Inserted
# value 유전 20180613 7803 Inserted
# value 토니스토리2: 고철왕국의 친구들 20180613 6441 Inserted
# value 데드풀 2 20180613 2637 Inserted
# value 벅스 프렌즈 20180613 2093 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180612 185617 Inserted
# value 독전 20180612 61751 Inserted
# value 유전 20180612 17405 Inserted
# value 아이 필 프리티 20180612 14812 Inserted
# value 데드풀 2 20180612 8218 Inserted
# value 허스토리 20180612 4558 Inserted
# value 탐정: 리턴즈 20180612 2787 Inserted
# value 어벤져스: 인피니티 워 20180612 2271 Inserted
# value 아바타 20180612 1455 Inserted
# value 버닝 20180612 1153 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180611 143984 Inserted
# value 독전 20180611 52889 Inserted
# value 아이 필 프리티 20180611 11246 Inserted
# value 유전 20180611 11234 Inserted
# value 데드풀 2 20180611 6564 Inserted
# value 탐정: 리턴즈 20180611 3330 Inserted
# value 허스토리 20180611 2409 Inserted
# value 어벤져스: 인피니티 워 20180611 1954 Inserted
# value 여중생A 20180611 1141 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180611 1046 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180610 703649 Inserted
# value 독전 20180610 148113 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180610 26292 Inserted
# value 아이 필 프리티 20180610 25607 Inserted
# value 유전 20180610 23632 Inserted
# value 데드풀 2 20180610 12481 Inserted
# value 벅스 프렌즈 20180610 6056 Inserted
# value 어벤져스: 인피니티 워 20180610 3575 Inserted
# value 피터 래빗 20180610 3173 Inserted
# value 호비와 매직 아일랜드 20180610 1947 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180609 791349 Inserted
# value 독전 20180609 168854 Inserted
# value 아이 필 프리티 20180609 28274 Inserted
# value 유전 20180609 28048 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180609 24723 Inserted
# value 데드풀 2 20180609 15829 Inserted
# value 벅스 프렌즈 20180609 5047 Inserted
# value 어벤져스: 인피니티 워 20180609 4062 Inserted
# value 피터 래빗 20180609 2685 Inserted
# value 버닝 20180609 2126 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180608 312529 Inserted
# value 독전 20180608 84347 Inserted
# value 유전 20180608 19800 Inserted
# value 아이 필 프리티 20180608 14009 Inserted
# value 데드풀 2 20180608 10421 Inserted
# value 어벤져스: 인피니티 워 20180608 2241 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180608 1605 Inserted
# value 버닝 20180608 1411 Inserted
# value 오션스8 20180608 1259 Inserted
# value 미드나잇 선 20180608 1003 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180607 231826 Inserted
# value 독전 20180607 68602 Inserted
# value 유전 20180607 17859 Inserted
# value 아이 필 프리티 20180607 11274 Inserted
# value 데드풀 2 20180607 8502 Inserted
# value 오션스8 20180607 2824 Inserted
# value 어벤져스: 인피니티 워 20180607 2055 Inserted
# value 탐정: 리턴즈 20180607 1908 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180607 1796 Inserted
# value 버닝 20180607 1289 Inserted
# value 쥬라기 월드: 폴른 킹덤 20180606 1183519 Inserted
# value 독전 20180606 230603 Inserted
# value 극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이 20180606 79574 Inserted
# value 데드풀 2 20180606 26547 Inserted
# value 아이 필 프리티 20180606 25708 Inserted
# value 벅스 프렌즈 20180606 12769 Inserted
# value 어벤져스: 인피니티 워 20180606 7434 Inserted
# value 피터 래빗 20180606 7238 Inserted
# value 트루스 오어 데어 20180606 4592 Inserted
# value 호비와 매직 아일랜드 20180606 3952 Inserted
# value 독전 20180605 155578 Inserted
# value 데드풀 2 20180605 35158 Inserted
# value 어벤져스: 인피니티 워 20180605 12503 Inserted
# value 트루스 오어 데어 20180605 7904 Inserted
# value 한 솔로: 스타워즈 스토리 20180605 4871 Inserted
# value 버닝 20180605 4531 Inserted
# value 스탠바이, 웬디 20180605 4498 Inserted
# value 데자뷰 20180605 2974 Inserted
# value 피터 래빗 20180605 1900 Inserted
# value 디트로이트 20180605 1877 Inserted
# value 독전 20180604 117689 Inserted
# value 데드풀 2 20180604 27514 Inserted
# value 어벤져스: 인피니티 워 20180604 8637 Inserted
# value 트루스 오어 데어 20180604 5673 Inserted
# value 한 솔로: 스타워즈 스토리 20180604 3553 Inserted
# value 버닝 20180604 3363 Inserted
# value 스탠바이, 웬디 20180604 3349 Inserted
# value 데자뷰 20180604 2453 Inserted
# value 디트로이트 20180604 1644 Inserted
# value 피터 래빗 20180604 1410 Inserted
# value 독전 20180603 366233 Inserted
# value 데드풀 2 20180603 77415 Inserted
# value 어벤져스: 인피니티 워 20180603 27224 Inserted
# value 피터 래빗 20180603 22829 Inserted
# value 트루스 오어 데어 20180603 21812 Inserted
# value 한 솔로: 스타워즈 스토리 20180603 13280 Inserted
# value 버닝 20180603 6488 Inserted
# value 스탠바이, 웬디 20180603 6482 Inserted
# value 데자뷰 20180603 5867 Inserted
# value 꼬마영웅 바비 20180603 5465 Inserted
# value 독전 20180602 421770 Inserted
# value 데드풀 2 20180602 101866 Inserted
# value 어벤져스: 인피니티 워 20180602 31033 Inserted
# value 트루스 오어 데어 20180602 25023 Inserted
# value 피터 래빗 20180602 21367 Inserted
# value 한 솔로: 스타워즈 스토리 20180602 15880 Inserted
# value 버닝 20180602 8056 Inserted
# value 스탠바이, 웬디 20180602 7348 Inserted
# value 데자뷰 20180602 7150 Inserted
# value 꼬마영웅 바비 20180602 5575 Inserted
# value 독전 20180601 193594 Inserted
# value 데드풀 2 20180601 51379 Inserted
# value 어벤져스: 인피니티 워 20180601 13433 Inserted
# value 트루스 오어 데어 20180601 11660 Inserted
# value 한 솔로: 스타워즈 스토리 20180601 7859 Inserted
# value 데자뷰 20180601 5872 Inserted
# value 버닝 20180601 5130 Inserted
# value 스탠바이, 웬디 20180601 4632 Inserted
# value 디트로이트 20180601 2140 Inserted
# value 피터 래빗 20180601 1970 Inserted
# value 독전 20180531 142368 Inserted
# value 데드풀 2 20180531 41960 Inserted
# value 어벤져스: 인피니티 워 20180531 10136 Inserted
# value 버닝 20180531 8589 Inserted
# value 트루스 오어 데어 20180531 6991 Inserted
# value 한 솔로: 스타워즈 스토리 20180531 6288 Inserted
# value 데자뷰 20180531 6138 Inserted
# value 스탠바이, 웬디 20180531 4212 Inserted
# value 탐정: 리턴즈 20180531 3322 Inserted
# value 디트로이트 20180531 2486 Inserted
# value 독전 20180530 299943 Inserted
# value 데드풀 2 20180530 81820 Inserted
# value 어벤져스: 인피니티 워 20180530 16391 Inserted
# value 트루스 오어 데어 20180530 15342 Inserted
# value 데자뷰 20180530 15214 Inserted
# value 한 솔로: 스타워즈 스토리 20180530 14721 Inserted
# value 버닝 20180530 9001 Inserted
# value 스탠바이, 웬디 20180530 6527 Inserted
# value 피터 래빗 20180530 3208 Inserted
# value 겨울왕국의 무민 20180530 2785 Inserted
# value 독전 20180529 137551 Inserted
# value 데드풀 2 20180529 44283 Inserted
# value 어벤져스: 인피니티 워 20180529 11182 Inserted
# value 트루스 오어 데어 20180529 10794 Inserted
# value 한 솔로: 스타워즈 스토리 20180529 9739 Inserted
# value 버닝 20180529 9295 Inserted
# value 피터 래빗 20180529 1937 Inserted
# value 안녕, 나의 소녀 20180529 1622 Inserted
# value 데자뷰 20180529 1205 Inserted
# value 레슬러 20180529 1063 Inserted
# value 독전 20180528 157099 Inserted
# value 데드풀 2 20180528 52592 Inserted
# value 어벤져스: 인피니티 워 20180528 12833 Inserted
# value 트루스 오어 데어 20180528 12489 Inserted
# value 한 솔로: 스타워즈 스토리 20180528 10165 Inserted
# value 버닝 20180528 8382 Inserted
# value 안녕, 나의 소녀 20180528 1667 Inserted
# value 피터 래빗 20180528 1589 Inserted
# value 세라비, 이것이 인생! 20180528 972 Inserted
# value 레이디 버드 20180528 791 Inserted
# value 독전 20180527 430064 Inserted
# value 데드풀 2 20180527 144836 Inserted
# value 어벤져스: 인피니티 워 20180527 42146 Inserted
# value 한 솔로: 스타워즈 스토리 20180527 40328 Inserted
# value 피터 래빗 20180527 37804 Inserted
# value 트루스 오어 데어 20180527 35621 Inserted
# value 버닝 20180527 16568 Inserted
# value 위 베어 베어스: 베이비 베어스 20180527 6096 Inserted
# value 안녕, 나의 소녀 20180527 4688 Inserted
# value 레슬러 20180527 1549 Inserted
# value 독전 20180526 459769 Inserted
# value 데드풀 2 20180526 186012 Inserted
# value 어벤져스: 인피니티 워 20180526 46992 Inserted
# value 한 솔로: 스타워즈 스토리 20180526 44135 Inserted
# value 트루스 오어 데어 20180526 38605 Inserted
# value 피터 래빗 20180526 34278 Inserted
# value 버닝 20180526 18629 Inserted
# value 안녕, 나의 소녀 20180526 5312 Inserted
# value 위 베어 베어스: 베이비 베어스 20180526 4890 Inserted
# value 레슬러 20180526 1884 Inserted
# value 독전 20180525 219564 Inserted
# value 데드풀 2 20180525 95108 Inserted
# value 트루스 오어 데어 20180525 23005 Inserted
# value 한 솔로: 스타워즈 스토리 20180525 20312 Inserted
# value 어벤져스: 인피니티 워 20180525 19045 Inserted
# value 버닝 20180525 13680 Inserted
# value 안녕, 나의 소녀 20180525 3422 Inserted
# value 피터 래빗 20180525 2602 Inserted
# value 레슬러 20180525 1573 Inserted
# value 챔피언 20180525 771 Inserted
# value 독전 20180524 158569 Inserted
# value 데드풀 2 20180524 75447 Inserted
# value 한 솔로: 스타워즈 스토리 20180524 19176 Inserted
# value 트루스 오어 데어 20180524 14919 Inserted
# value 어벤져스: 인피니티 워 20180524 14346 Inserted
# value 버닝 20180524 11934 Inserted
# value 레슬러 20180524 5058 Inserted
# value 안녕, 나의 소녀 20180524 2710 Inserted
# value 피터 래빗 20180524 1854 Inserted
# value 세라비, 이것이 인생! 20180524 999 Inserted
# image saved
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# image saved
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# image saved

# %%
#this is parent module of insert_trend
smd.insert_movie_audiance_num_per_date(datetime.datetime.now().date(), 2)
# Out:
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists
# DataExists

# %%
def query_and_draw(time):
    today = datetime.datetime.now()
    week = datetime.timedelta(time)
    a_week_ago = (today - week).date()
    print(today.date(), a_week_ago.strftime("%Y-%m-%d"))
    return smd.query_and_draw(today.date(), a_week_ago)

# %%
query_and_draw(7)
# Out:
# 2018-06-14 2018-06-07
# image saved

# %%
query_and_draw(14)
# Out:
# 2018-06-14 2018-05-31
# image saved

# %%
query_and_draw(30)
# Out:
# 2018-06-14 2018-05-15
# image saved

# %%
#
